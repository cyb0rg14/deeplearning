# %%
import gymnasium as gym

env = gym.make('LunarLander-v2', render_mode='humna')
observation, info = env.reset()
# Out:
# Running cells with 'Python 3.12.3' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/bin/python -m pip install ipykernel -U --user --force-reinstall'

# %%
# !/bin/python -m pip install ipykernel -U --user --force-reinstall
# Out:
# Running cells with 'Python 3.12.3' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/sbin/python -m pip install ipykernel -U --user --force-reinstall'
